# %% [markdown]
# # Task 3.1 — Two-Component Ablation
#
# [Ablate two distinct components (one at a time). For each: component name/role, ablated code, plot/table in partB/results/, and 5–7 sentence interpretation.]
