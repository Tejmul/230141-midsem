# %% [markdown]
# # Task 3.2 — Failure Mode
#
# [Describe one scenario where the method fails, code + plot in partB/results/, explanation linking to Task 1.2 assumptions, and one suggested modification.]
