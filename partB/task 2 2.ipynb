# %% [markdown]
# # Task 2.2 — Reproduction of One Contribution
#
# [State which result/contribution you are reproducing and the evaluation metric. Implement the method with code-to-paper annotations.]
